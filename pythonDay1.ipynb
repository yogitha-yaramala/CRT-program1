# %%
2+2
# Out:
# 4

# %% [markdown]
# # Markdown
# ## Markdown
# ### Markdown
# #### Markdown

# %% [markdown]
# # 'Markdown'

# %% [markdown]
# * in*Markdown

# %% [markdown]
# * *Markdown*

# %% [markdown]
# * * yogitha*

# %% [markdown]
# * *yogitha*

# %% [markdown]
# * **yogitha**

# %% [markdown]
# * ***yogitha***

# %% [markdown]
# -Normal text

# %% [markdown]
# - Normal Text

# %% [markdown]
# - Heading
#  - subheading

# %% [markdown]
# [![image.png](attachment:image.png)]

# %% [markdown]
# [https://www.wonderopolis.org/wp-content/uploads/2011/06/fresh-thick-grass_shutterstock_71481652.jpg]

# %% [markdown]
# ![imaage](https://www.wonderopolis.org/wp-content/uploads/2011/06/fresh-thick-grass_shutterstock_71481652.jpg)

# %% [markdown]
# [1]https://drive.google.com/drive/my-drive

# %% [markdown]
# [1]:https://drive.google.com/drive/my-drive

# %% [markdown]
# * [CRT]
# [CRT]:https://drive.google.com/drive/my-drive

# %%
print("yogitha")
# Out:
# yogitha

# %%
print("Hello, Gitam")
print("hi")
# Out:
# Hello, Gitam
# hi

# %%
print("Hello, gitam",end="@")
print("yogitha")
# Out:
# Hello, gitam@yogitha

# %%
a=10
a=b=c=1
a,b,c=1,2,3

# %%
a="python"
b="p"
print(type(a))
c=10
type(c)
# Out:
# <class 'str'>
# int

# %%
a=10.3
type(a)
# Out:
# float

# %%
a=10.5
print(type(a))
id(a)
# Out:
# <class 'float'>
# 63396128

# %%
name="yogitha"
age="20"
print("my name is",name,"age is",age)
# Out:
# my name is yogitha age is 20

# %%
input("enter the string")
# Out:
# enter the stringhyderabad
# 'hyderabad'

# %%
b=input("enter the number")
 type(b)
# Out:
#   File "<ipython-input-1-0217a7f3257f>", line 2
#     type(b)
#     ^
# IndentationError: unexpected indent

# %%
a=int(input("enter a number"))
type(a)
# Out:
# enter a number123
# int

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
c=a+b
print(c)
# Out:
# enter a number7
# enter a number8
# 15

# %%
a=1
print(a)
type(a)
# Out:
# 1
# int

# %%
b=1.2
print(b)
type(b)
# Out:
# 1.2
# float

# %%
c=1+3j
print(c)
type(c)
# Out:
# (1+3j)
# complex

# %%
d=float(12)
d
# Out:
# 12.0

# %%
a=complex(1,2)
a
# Out:
# (1+2j)

# %%
a=complex(1,2)
b=complex(3,4)
a+b
# Out:
# (4+6j)

# %%
a=True
type(a)
# Out:
# bool

# %%
a=5
b=6
a>b
# Out:
# False

# %%
s1="abc"
s2='abc'
print(s1)
s2
# Out:
# abc
# 'abc'

# %%
type(s1)
type(s2)
# Out:
# str

# %%
i=100
print(type(i))
# Out:
# <class 'int'>

# %%
s1=str(i)
print(s1)
type(s1)
# Out:
# 100
# str

# %%
f1=float(i)
print(f1)
type(f1)
# Out:
# 100.0
# float

# %%
s="100"
print(type(s))
# Out:
# <class 'str'>

# %%
a=int(s)
type(a)
# Out:
# int

# %%
f=1.5
type(f)
# Out:
# float

# %%
a1=int(f)
type(a)
# Out:
# int

# %%
a="1234"
len(a)
# Out:
# 4

# %%
a="123456789"
len(a)
# Out:
# 9

# %%
a=10
b=20
print("addition is",a+b)
print("subtraction is",a-b)
print("multiplication is",a*b)
print("division is",a/b)
# Out:
# addition is 30
# subtraction is -10
# multiplication is 200
# division is 0.5

# %%
20/10
# Out:
# 2.0

# %%
20%10
# Out:
# 0

# %%
2**2
# Out:
# 4

# %%
2**5
# Out:
# 32

# %%
4//2
# Out:
# 2

# %% [markdown]
# 12/5

# %%
12//5
# Out:
# 2

# %%
-12//5
# Out:
# -3

# %%
a=2
b=3
print(a>=5and a<10)
print(a>=5or a<=10)
print(not(a))
# Out:
# False
# True
# False

# %%
a=2
b=3
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# False
# True

# %%
str1="abc"
print('a' in str1)
print('a'not in str1)
# Out:
# True
# False

# %%
a=10
if a>0:
    print("positive")
# Out:
# positive

# %%
a=20
b=10
if a>b:
    print("a is greater")
else:
    print("b is greater")
# Out:
# a is greater

# %%
a=20
b=20
if a>b:
    print("a is greater")
elif a<b:
    print("b is grater")
else:
    print("neutral")
# Out:
# neutral
